# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    #print(source_text)
    #print(target_text)
    source_token_ids = []
    target_token_ids = []

    for srcLine in source_text.split('\n'):
        src_line_token_ids = []
        for srcWord in srcLine.split():
            src_line_token_ids.append(source_vocab_to_int[srcWord])
        source_token_ids.append(src_line_token_ids)
        
    for tgtLine in target_text.split('\n'):
        tgt_line_token_ids = []
        for tgtWord in tgtLine.split():
            tgt_line_token_ids.append(target_vocab_to_int[tgtWord])
        tgt_line_token_ids.append(target_vocab_to_int['<EOS>'])
        target_token_ids.append(tgt_line_token_ids)

    
    #print(source_token_ids)
    #print(target_token_ids)
    return source_token_ids, target_token_ids

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.2.1
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    inputs = tf.placeholder(tf.int32, [None, None], name = 'input')
    targets = tf.placeholder(tf.int32, [None, None], name = 'targets')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    target_sequence_length = tf.placeholder(tf.int32, (None,), name='target_sequence_length')
    max_target_len = tf.reduce_max(target_sequence_length, name='max_target_len')
    source_sequence_length = tf.placeholder(tf.int32, (None,), name='source_sequence_length')
    
    return inputs, targets, learning_rate, keep_prob, target_sequence_length, max_target_len, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_2/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/usr/local/lib/python3.5/runpy.py", line 193, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/usr/local/lib/python3.5/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/usr/local/lib/python3.5/site-packages/ipykernel_launcher.py", line 16, in <module>\n    app.launch_new_instance()', 'File "/usr/local/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance\n    app.start()', 'File "/usr/local/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 477, in start\n    ioloop.IOLoop.instance().start()', 'File "/usr/local/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 177, in start\n    super(ZMQIOLoop, self).start()', 'File "/usr/local/lib/python3.5/site-packages/tornado/ioloop.py", line 888, in start\n    handler_func(fd_obj, events)', 'File "/usr/local/lib/python3.5/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/usr/local/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "/usr/local/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/usr/local/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "/usr/local/lib/python3.5/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/usr/local/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/usr/local/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/usr/local/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 399, in execute_request\n    user_expressions, allow_stdin)', 'File "/usr/local/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/usr/local/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 533, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2808, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-8-2e6796aa2de3>", line 21, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/output/problem_unittests.py", line 106, in test_model_inputs\n    assert tf.assert_rank(lr, 0, message=\'Learning Rate has wrong rank\')', 'File "/usr/local/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/usr/local/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "/usr/local/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 170, in wrapped\n    return _add_should_use_warning(fn(*args, **kwargs))', 'File "/usr/local/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 139, in _add_should_use_warning\n    wrapped = TFShouldUseWarningWrapper(x)', 'File "/usr/local/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 96, in __init__\n    stack = [s.strip() for s in traceback.format_stack()]']
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_3/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/usr/local/lib/python3.5/runpy.py", line 193, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/usr/local/lib/python3.5/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/usr/local/lib/python3.5/site-packages/ipykernel_launcher.py", line 16, in <module>\n    app.launch_new_instance()', 'File "/usr/local/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance\n    app.start()', 'File "/usr/local/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 477, in start\n    ioloop.IOLoop.instance().start()', 'File "/usr/local/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 177, in start\n    super(ZMQIOLoop, self).start()', 'File "/usr/local/lib/python3.5/site-packages/tornado/ioloop.py", line 888, in start\n    handler_func(fd_obj, events)', 'File "/usr/local/lib/python3.5/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/usr/local/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "/usr/local/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/usr/local/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "/usr/local/lib/python3.5/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/usr/local/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/usr/local/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/usr/local/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 399, in execute_request\n    user_expressions, allow_stdin)', 'File "/usr/local/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/usr/local/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 533, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2808, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-8-2e6796aa2de3>", line 21, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/output/problem_unittests.py", line 107, in test_model_inputs\n    assert tf.assert_rank(keep_prob, 0, message=\'Keep Probability has wrong rank\')', 'File "/usr/local/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/usr/local/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "/usr/local/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 170, in wrapped\n    return _add_should_use_warning(fn(*args, **kwargs))', 'File "/usr/local/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 139, in _add_should_use_warning\n    wrapped = TFShouldUseWarningWrapper(x)', 'File "/usr/local/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py", line 96, in __init__\n    stack = [s.strip() for s in traceback.format_stack()]']
# ==================================
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    '''Remove the last word id from each batch and concat the <GO> to the begining of each batch'''
    """
    For more details, refer to 
    1. https://github.com/udacity/deep-learning/blob/master/seq2seq/sequence_to_sequence_implementation.ipynb
    2. https://stackoverflow.com/questions/41380126/what-does-tf-strided-slice-do
    """
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # Encoder embedding
    encoder_embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)

    # RNN cell
    def make_cell(rnn_size):
        lstm_cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        
        lstm_cell_w_dropout = tf.nn.rnn_cell.DropoutWrapper(lstm_cell, output_keep_prob=keep_prob, seed=42)
        return lstm_cell_w_dropout

    encoder_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    encoder_output, encoder_state = tf.nn.dynamic_rnn(encoder_cell, encoder_embed_input, sequence_length=source_sequence_length, dtype=tf.float32)

    return encoder_output, encoder_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    Training helper ->
    https://stackoverflow.com/questions/43826784/trouble-understanding-tf-contrib-seq2seq-traininghelper
    
    TrainingHelper feeds the ground truth at every step. If you want to use decoder outputs, you can use scheduled sampling [1]. 
    Scheduled sampling is implemented in ScheduledEmbeddingTrainingHelper and ScheduledOutputTrainingHelper, so you can use 
    one of the two (depending on your particular application) instead of TrainingHelper. 
    """
    # 1. Decoder Embedding
    # already passed as input -> dec_embed_input

    # 2. Construct the decoder cell
    # already passed as input -> dec_cell
     
    # 3. Dense layer to translate the decoder's output at each time 
    # step into a choice from the target vocabulary
    # already passed as input -> output_layer

    # 4. Set up a training decoder
    # Training Decoder
    #with tf.variable_scope("decode"):

    # Helper for the training process. Used by BasicDecoder to read inputs.
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input,
                                                        sequence_length=target_sequence_length,
                                                        time_major=False)


    # Basic decoder
    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                       training_helper,
                                                       encoder_state,
                                                       output_layer) 

    # Perform dynamic decoding using the decoder
    training_decoder_output = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                                                   impute_finished=True,
                                                                   maximum_iterations=max_summary_length)[0]

    return training_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # Reuses the same parameters trained by the training process
    # with tf.variable_scope("decode", reuse=True):
    # will be in the callee
    """
    Constructs a tensor by tiling a given tensor.
    This operation creates a new tensor by replicating input multiples times. The output tensor's i'th dimension has 
    input.dims(i) * multiples[i] elements, and the values of input are replicated multiples[i] times along 
    the 'i'th dimension. For example, tiling [a b c d] by [2] produces [a b c d a b c d].
    """
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')

    """
    As you can see, this is very similar to the training layer. The main difference is GreedyEmbeddingHelper, which uses the
    argmax of the output (treated as logits) and passes the result through an embedding layer to get the next input. 
    """
    # Helper for the inference process.
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                            start_tokens,
                                                            end_of_sequence_id)

    # Basic decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                    inference_helper,
                                                    encoder_state,
                                                    output_layer)

    # Perform dynamic decoding using the decoder
    inference_decoder_output = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                        impute_finished=True,
                                                        maximum_iterations=max_target_sequence_length)[0]
    
    return inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    #1. Embed the target sequences
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    #2. Construct the decoder LSTM cell (just like you constructed the encoder cell above)
    def make_cell(rnn_size):
        dec_cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        return dec_cell

    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])    
    
    
    #3. Create an output layer to map the outputs of the decoder to the elements of our vocabulary
    # Functional interface for the densely (fully)-connected layer.
    output_layer = Dense(target_vocab_size,
                         kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))
    
    #Note: You'll need to use tf.variable_scope to share variables between training and inference.
    #4. Use the your decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, 
    #   max_target_sequence_length, output_layer, keep_prob) function to get the training logits.
    # read about variable scope -- https://stackoverflow.com/questions/35919020/whats-the-difference-of-name-scope-and-a-variable-scope-in-tensorflow
    with tf.variable_scope("decode"):
        training_decoder_output = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                                                     target_sequence_length, max_target_sequence_length, 
                                                     output_layer, keep_prob)
        
    #5. Use your decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, 
    #   max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob) function to get the inference logits.
    with tf.variable_scope("decode", reuse=True):
        inference_logits = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, target_vocab_to_int['<GO>'], 
                                                target_vocab_to_int['<EOS>'], max_target_sequence_length, target_vocab_size, output_layer, 
                                                batch_size, keep_prob)
    
    return training_decoder_output, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # Encode the input using your encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size).
    enc_output, enc_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, source_sequence_length, source_vocab_size, enc_embedding_size)
    
    # Process target data using your process_decoder_input(target_data, target_vocab_to_int, batch_size) function.
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    # Decode the encoded input using your decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size) function.
    Training_BasicDecoderOutput, Inference_BasicDecoderOutput = decoding_layer(dec_input, enc_state, target_sequence_length, 
                                                                               max_target_sentence_length, rnn_size, num_layers, 
                                                                               target_vocab_to_int, target_vocab_size, batch_size,
                                                                               keep_prob, dec_embedding_size)
    
    # TODO: Implement Function
    return Training_BasicDecoderOutput, Inference_BasicDecoderOutput


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 7
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 64
# Number of Layers
num_layers = 3
# Embedding Size
encoding_embedding_size = 256
decoding_embedding_size = 256
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.7
display_step = 20

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.2695, Validation Accuracy: 0.3356, Loss: 4.2113
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.2680, Validation Accuracy: 0.3363, Loss: 3.4359
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.2987, Validation Accuracy: 0.3363, Loss: 3.1188
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.3121, Validation Accuracy: 0.3686, Loss: 3.0662
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.3090, Validation Accuracy: 0.3796, Loss: 3.0095
# Epoch   0 Batch  120/1077 - Train Accuracy: 0.3195, Validation Accuracy: 0.3810, Loss: 2.9117
# Epoch   0 Batch  140/1077 - Train Accuracy: 0.2919, Validation Accuracy: 0.3928, Loss: 2.9759
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.3398, Validation Accuracy: 0.3988, Loss: 2.7366
# Epoch   0 Batch  180/1077 - Train Accuracy: 0.3695, Validation Accuracy: 0.4261, Loss: 2.6995
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.3855, Validation Accuracy: 0.4393, Loss: 2.6498
# Epoch   0 Batch  220/1077 - Train Accuracy: 0.3919, Validation Accuracy: 0.4531, Loss: 2.6658
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.4301, Validation Accuracy: 0.4677, Loss: 2.4873
# Epoch   0 Batch  260/1077 - Train Accuracy: 0.4583, Validation Accuracy: 0.4790, Loss: 2.4122
# Epoch   0 Batch  280/1077 - Train Accuracy: 0.4465, Validation Accuracy: 0.4872, Loss: 2.4600
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.4248, Validation Accuracy: 0.4957, Loss: 2.5435
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.4484, Validation Accuracy: 0.4805, Loss: 2.4048
# Epoch   0 Batch  340/1077 - Train Accuracy: 0.4313, Validation Accuracy: 0.5018, Loss: 2.4432
# Epoch   0 Batch  360/1077 - Train Accuracy: 0.4602, Validation Accuracy: 0.5021, Loss: 2.3209
# Epoch   0 Batch  380/1077 - Train Accuracy: 0.4684, Validation Accuracy: 0.4904, Loss: 2.2165
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.4594, Validation Accuracy: 0.5099, Loss: 2.2609
# Epoch   0 Batch  420/1077 - Train Accuracy: 0.4531, Validation Accuracy: 0.5021, Loss: 2.1796
# Epoch   0 Batch  440/1077 - Train Accuracy: 0.4648, Validation Accuracy: 0.5067, Loss: 2.1356
# Epoch   0 Batch  460/1077 - Train Accuracy: 0.4523, Validation Accuracy: 0.5135, Loss: 2.1298
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.4655, Validation Accuracy: 0.5142, Loss: 2.1010
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.4805, Validation Accuracy: 0.5103, Loss: 2.0002
# Epoch   0 Batch  520/1077 - Train Accuracy: 0.4985, Validation Accuracy: 0.5245, Loss: 1.8709
# Epoch   0 Batch  540/1077 - Train Accuracy: 0.4832, Validation Accuracy: 0.5124, Loss: 1.8485
# Epoch   0 Batch  560/1077 - Train Accuracy: 0.4859, Validation Accuracy: 0.5178, Loss: 1.8509
# Epoch   0 Batch  580/1077 - Train Accuracy: 0.5067, Validation Accuracy: 0.5178, Loss: 1.7605
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.4989, Validation Accuracy: 0.5067, Loss: 1.7085
# Epoch   0 Batch  620/1077 - Train Accuracy: 0.4715, Validation Accuracy: 0.5085, Loss: 1.7524
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.4803, Validation Accuracy: 0.5124, Loss: 1.6575
# Epoch   0 Batch  660/1077 - Train Accuracy: 0.4766, Validation Accuracy: 0.5181, Loss: 1.7135
# Epoch   0 Batch  680/1077 - Train Accuracy: 0.4758, Validation Accuracy: 0.5067, Loss: 1.6092
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.4672, Validation Accuracy: 0.5174, Loss: 1.5831
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.4626, Validation Accuracy: 0.5078, Loss: 1.6963
# Epoch   0 Batch  740/1077 - Train Accuracy: 0.4813, Validation Accuracy: 0.5131, Loss: 1.5296
# Epoch   0 Batch  760/1077 - Train Accuracy: 0.4445, Validation Accuracy: 0.4950, Loss: 1.5322
# Epoch   0 Batch  780/1077 - Train Accuracy: 0.4645, Validation Accuracy: 0.5178, Loss: 1.5012
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.4234, Validation Accuracy: 0.4993, Loss: 1.4929
# Epoch   0 Batch  820/1077 - Train Accuracy: 0.4266, Validation Accuracy: 0.5046, Loss: 1.4397
# Epoch   0 Batch  840/1077 - Train Accuracy: 0.4598, Validation Accuracy: 0.5277, Loss: 1.3664
# Epoch   0 Batch  860/1077 - Train Accuracy: 0.4821, Validation Accuracy: 0.5178, Loss: 1.2950
# Epoch   0 Batch  880/1077 - Train Accuracy: 0.4945, Validation Accuracy: 0.5046, Loss: 1.2569
# Epoch   0 Batch  900/1077 - Train Accuracy: 0.4691, Validation Accuracy: 0.5107, Loss: 1.3139
# Epoch   0 Batch  920/1077 - Train Accuracy: 0.4723, Validation Accuracy: 0.5103, Loss: 1.2512
# Epoch   0 Batch  940/1077 - Train Accuracy: 0.4742, Validation Accuracy: 0.5234, Loss: 1.2434
# Epoch   0 Batch  960/1077 - Train Accuracy: 0.5301, Validation Accuracy: 0.5344, Loss: 1.1271
# Epoch   0 Batch  980/1077 - Train Accuracy: 0.5172, Validation Accuracy: 0.5387, Loss: 1.1385
# Epoch   0 Batch 1000/1077 - Train Accuracy: 0.5432, Validation Accuracy: 0.5220, Loss: 1.0758
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.5109, Validation Accuracy: 0.5398, Loss: 1.0966
# Epoch   0 Batch 1040/1077 - Train Accuracy: 0.4782, Validation Accuracy: 0.5352, Loss: 1.1448
# Epoch   0 Batch 1060/1077 - Train Accuracy: 0.5008, Validation Accuracy: 0.5231, Loss: 1.0540
# Epoch   1 Batch   20/1077 - Train Accuracy: 0.5094, Validation Accuracy: 0.5273, Loss: 0.9996
# Epoch   1 Batch   40/1077 - Train Accuracy: 0.5059, Validation Accuracy: 0.5494, Loss: 1.0192
# Epoch   1 Batch   60/1077 - Train Accuracy: 0.5186, Validation Accuracy: 0.5558, Loss: 0.9763
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.4836, Validation Accuracy: 0.5327, Loss: 0.9950
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.5105, Validation Accuracy: 0.5288, Loss: 0.9692
# Epoch   1 Batch  120/1077 - Train Accuracy: 0.5008, Validation Accuracy: 0.5433, Loss: 0.9636
# Epoch   1 Batch  140/1077 - Train Accuracy: 0.4877, Validation Accuracy: 0.5376, Loss: 0.9817
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.5574, Validation Accuracy: 0.5600, Loss: 0.8968
# Epoch   1 Batch  180/1077 - Train Accuracy: 0.5164, Validation Accuracy: 0.5490, Loss: 0.9003
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.5203, Validation Accuracy: 0.5458, Loss: 0.9021
# Epoch   1 Batch  220/1077 - Train Accuracy: 0.4992, Validation Accuracy: 0.5415, Loss: 0.8964
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.5406, Validation Accuracy: 0.5625, Loss: 0.8365
# Epoch   1 Batch  260/1077 - Train Accuracy: 0.5480, Validation Accuracy: 0.5462, Loss: 0.8101
# Epoch   1 Batch  280/1077 - Train Accuracy: 0.5430, Validation Accuracy: 0.5504, Loss: 0.8666
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.4901, Validation Accuracy: 0.5522, Loss: 0.8659
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.5316, Validation Accuracy: 0.5657, Loss: 0.8384
# Epoch   1 Batch  340/1077 - Train Accuracy: 0.4803, Validation Accuracy: 0.5696, Loss: 0.8244
# Epoch   1 Batch  360/1077 - Train Accuracy: 0.5437, Validation Accuracy: 0.5664, Loss: 0.8109
# Epoch   1 Batch  380/1077 - Train Accuracy: 0.5520, Validation Accuracy: 0.5710, Loss: 0.7673
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.5723, Validation Accuracy: 0.5842, Loss: 0.7849
# Epoch   1 Batch  420/1077 - Train Accuracy: 0.5684, Validation Accuracy: 0.5895, Loss: 0.7641
# Epoch   1 Batch  440/1077 - Train Accuracy: 0.5707, Validation Accuracy: 0.6040, Loss: 0.8022
# Epoch   1 Batch  460/1077 - Train Accuracy: 0.5832, Validation Accuracy: 0.5969, Loss: 0.7738
# Epoch   1 Batch  480/1077 - Train Accuracy: 0.5580, Validation Accuracy: 0.5980, Loss: 0.7658
# Epoch   1 Batch  500/1077 - Train Accuracy: 0.5953, Validation Accuracy: 0.6040, Loss: 0.7406
# Epoch   1 Batch  520/1077 - Train Accuracy: 0.6146, Validation Accuracy: 0.6254, Loss: 0.6949
# Epoch   1 Batch  540/1077 - Train Accuracy: 0.6164, Validation Accuracy: 0.6175, Loss: 0.6793
# Epoch   1 Batch  560/1077 - Train Accuracy: 0.5953, Validation Accuracy: 0.6264, Loss: 0.7014
# Epoch   1 Batch  580/1077 - Train Accuracy: 0.6496, Validation Accuracy: 0.6211, Loss: 0.6516
# Epoch   1 Batch  600/1077 - Train Accuracy: 0.6116, Validation Accuracy: 0.6282, Loss: 0.6692
# Epoch   1 Batch  620/1077 - Train Accuracy: 0.6062, Validation Accuracy: 0.6378, Loss: 0.6817
# Epoch   1 Batch  640/1077 - Train Accuracy: 0.5945, Validation Accuracy: 0.6374, Loss: 0.6579
# Epoch   1 Batch  660/1077 - Train Accuracy: 0.6062, Validation Accuracy: 0.6516, Loss: 0.7025
# Epoch   1 Batch  680/1077 - Train Accuracy: 0.6507, Validation Accuracy: 0.6406, Loss: 0.6367
# Epoch   1 Batch  700/1077 - Train Accuracy: 0.5980, Validation Accuracy: 0.6410, Loss: 0.6429
# Epoch   1 Batch  720/1077 - Train Accuracy: 0.6275, Validation Accuracy: 0.6488, Loss: 0.6897
# Epoch   1 Batch  740/1077 - Train Accuracy: 0.6441, Validation Accuracy: 0.6506, Loss: 0.6335
# Epoch   1 Batch  760/1077 - Train Accuracy: 0.6422, Validation Accuracy: 0.6559, Loss: 0.6357
# Epoch   1 Batch  780/1077 - Train Accuracy: 0.6324, Validation Accuracy: 0.6410, Loss: 0.6483
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.6180, Validation Accuracy: 0.6474, Loss: 0.6204
# Epoch   1 Batch  820/1077 - Train Accuracy: 0.6195, Validation Accuracy: 0.6555, Loss: 0.6304
# Epoch   1 Batch  840/1077 - Train Accuracy: 0.6680, Validation Accuracy: 0.6520, Loss: 0.5900
# Epoch   1 Batch  860/1077 - Train Accuracy: 0.6376, Validation Accuracy: 0.6541, Loss: 0.5830
# Epoch   1 Batch  880/1077 - Train Accuracy: 0.6695, Validation Accuracy: 0.6562, Loss: 0.5737
# Epoch   1 Batch  900/1077 - Train Accuracy: 0.6633, Validation Accuracy: 0.6584, Loss: 0.5974
# Epoch   1 Batch  920/1077 - Train Accuracy: 0.6395, Validation Accuracy: 0.6523, Loss: 0.5865
# Epoch   1 Batch  940/1077 - Train Accuracy: 0.6121, Validation Accuracy: 0.6531, Loss: 0.5695
# Epoch   1 Batch  960/1077 - Train Accuracy: 0.6458, Validation Accuracy: 0.6477, Loss: 0.5415
# Epoch   1 Batch  980/1077 - Train Accuracy: 0.6512, Validation Accuracy: 0.6616, Loss: 0.5518
# Epoch   1 Batch 1000/1077 - Train Accuracy: 0.6637, Validation Accuracy: 0.6662, Loss: 0.5184
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.6684, Validation Accuracy: 0.6765, Loss: 0.5173
# Epoch   1 Batch 1040/1077 - Train Accuracy: 0.6369, Validation Accuracy: 0.6520, Loss: 0.5642
# Epoch   1 Batch 1060/1077 - Train Accuracy: 0.6641, Validation Accuracy: 0.6449, Loss: 0.5196
# Epoch   2 Batch   20/1077 - Train Accuracy: 0.6750, Validation Accuracy: 0.6662, Loss: 0.4949
# Epoch   2 Batch   40/1077 - Train Accuracy: 0.6418, Validation Accuracy: 0.6456, Loss: 0.5139
# Epoch   2 Batch   60/1077 - Train Accuracy: 0.6618, Validation Accuracy: 0.6626, Loss: 0.4878
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.6746, Validation Accuracy: 0.6477, Loss: 0.4945
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.6898, Validation Accuracy: 0.6815, Loss: 0.5023
# Epoch   2 Batch  120/1077 - Train Accuracy: 0.6797, Validation Accuracy: 0.6634, Loss: 0.5045
# Epoch   2 Batch  140/1077 - Train Accuracy: 0.6715, Validation Accuracy: 0.6935, Loss: 0.4936
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.6980, Validation Accuracy: 0.6907, Loss: 0.4613
# Epoch   2 Batch  180/1077 - Train Accuracy: 0.7180, Validation Accuracy: 0.6786, Loss: 0.4627
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.6949, Validation Accuracy: 0.6964, Loss: 0.4862
# Epoch   2 Batch  220/1077 - Train Accuracy: 0.6904, Validation Accuracy: 0.6918, Loss: 0.4803
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.7117, Validation Accuracy: 0.6903, Loss: 0.4463
# Epoch   2 Batch  260/1077 - Train Accuracy: 0.7139, Validation Accuracy: 0.6747, Loss: 0.4155
# Epoch   2 Batch  280/1077 - Train Accuracy: 0.7219, Validation Accuracy: 0.7031, Loss: 0.4631
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.6653, Validation Accuracy: 0.7013, Loss: 0.4550
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.7016, Validation Accuracy: 0.6857, Loss: 0.4527
# Epoch   2 Batch  340/1077 - Train Accuracy: 0.7007, Validation Accuracy: 0.6776, Loss: 0.4351
# Epoch   2 Batch  360/1077 - Train Accuracy: 0.7348, Validation Accuracy: 0.6839, Loss: 0.4336
# Epoch   2 Batch  380/1077 - Train Accuracy: 0.7195, Validation Accuracy: 0.7177, Loss: 0.4060
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.7094, Validation Accuracy: 0.7156, Loss: 0.4294
# Epoch   2 Batch  420/1077 - Train Accuracy: 0.7434, Validation Accuracy: 0.6886, Loss: 0.3992
# Epoch   2 Batch  440/1077 - Train Accuracy: 0.7086, Validation Accuracy: 0.6967, Loss: 0.4148
# Epoch   2 Batch  460/1077 - Train Accuracy: 0.7371, Validation Accuracy: 0.7276, Loss: 0.4183
# Epoch   2 Batch  480/1077 - Train Accuracy: 0.7245, Validation Accuracy: 0.7028, Loss: 0.4169
# Epoch   2 Batch  500/1077 - Train Accuracy: 0.7520, Validation Accuracy: 0.7276, Loss: 0.3904
# Epoch   2 Batch  520/1077 - Train Accuracy: 0.7608, Validation Accuracy: 0.7440, Loss: 0.3803
# Epoch   2 Batch  540/1077 - Train Accuracy: 0.7301, Validation Accuracy: 0.7131, Loss: 0.3569
# Epoch   2 Batch  560/1077 - Train Accuracy: 0.7488, Validation Accuracy: 0.7681, Loss: 0.3752
# Epoch   2 Batch  580/1077 - Train Accuracy: 0.7708, Validation Accuracy: 0.7653, Loss: 0.3578
# Epoch   2 Batch  600/1077 - Train Accuracy: 0.7232, Validation Accuracy: 0.7450, Loss: 0.3683
# Epoch   2 Batch  620/1077 - Train Accuracy: 0.7375, Validation Accuracy: 0.7504, Loss: 0.3666
# Epoch   2 Batch  640/1077 - Train Accuracy: 0.7604, Validation Accuracy: 0.7624, Loss: 0.3498
# Epoch   2 Batch  660/1077 - Train Accuracy: 0.7430, Validation Accuracy: 0.7415, Loss: 0.3728
# Epoch   2 Batch  680/1077 - Train Accuracy: 0.7623, Validation Accuracy: 0.7710, Loss: 0.3436
# Epoch   2 Batch  700/1077 - Train Accuracy: 0.7828, Validation Accuracy: 0.7678, Loss: 0.3370
# Epoch   2 Batch  720/1077 - Train Accuracy: 0.7426, Validation Accuracy: 0.7521, Loss: 0.3757
# Epoch   2 Batch  740/1077 - Train Accuracy: 0.7508, Validation Accuracy: 0.7852, Loss: 0.3407
# Epoch   2 Batch  760/1077 - Train Accuracy: 0.7203, Validation Accuracy: 0.7560, Loss: 0.3667
# Epoch   2 Batch  780/1077 - Train Accuracy: 0.7383, Validation Accuracy: 0.7624, Loss: 0.3688
# Epoch   2 Batch  800/1077 - Train Accuracy: 0.7859, Validation Accuracy: 0.7908, Loss: 0.3326
# Epoch   2 Batch  820/1077 - Train Accuracy: 0.7492, Validation Accuracy: 0.7852, Loss: 0.3426
# Epoch   2 Batch  840/1077 - Train Accuracy: 0.7891, Validation Accuracy: 0.7958, Loss: 0.3253
# Epoch   2 Batch  860/1077 - Train Accuracy: 0.7533, Validation Accuracy: 0.7749, Loss: 0.3370
# Epoch   2 Batch  880/1077 - Train Accuracy: 0.8012, Validation Accuracy: 0.7809, Loss: 0.3155
# Epoch   2 Batch  900/1077 - Train Accuracy: 0.7828, Validation Accuracy: 0.8033, Loss: 0.3396
# Epoch   2 Batch  920/1077 - Train Accuracy: 0.7781, Validation Accuracy: 0.8150, Loss: 0.3365
# Epoch   2 Batch  940/1077 - Train Accuracy: 0.7871, Validation Accuracy: 0.7816, Loss: 0.3076
# Epoch   2 Batch  960/1077 - Train Accuracy: 0.7649, Validation Accuracy: 0.7770, Loss: 0.2918
# Epoch   2 Batch  980/1077 - Train Accuracy: 0.7523, Validation Accuracy: 0.7781, Loss: 0.3122
# Epoch   2 Batch 1000/1077 - Train Accuracy: 0.8155, Validation Accuracy: 0.7887, Loss: 0.2807
# Epoch   2 Batch 1020/1077 - Train Accuracy: 0.8121, Validation Accuracy: 0.7905, Loss: 0.2828
# Epoch   2 Batch 1040/1077 - Train Accuracy: 0.7928, Validation Accuracy: 0.7834, Loss: 0.3209
# Epoch   2 Batch 1060/1077 - Train Accuracy: 0.8102, Validation Accuracy: 0.7844, Loss: 0.2859
# Epoch   3 Batch   20/1077 - Train Accuracy: 0.7859, Validation Accuracy: 0.7809, Loss: 0.2555
# Epoch   3 Batch   40/1077 - Train Accuracy: 0.7906, Validation Accuracy: 0.8121, Loss: 0.2774
# Epoch   3 Batch   60/1077 - Train Accuracy: 0.8285, Validation Accuracy: 0.8068, Loss: 0.2677
# Epoch   3 Batch   80/1077 - Train Accuracy: 0.7977, Validation Accuracy: 0.7962, Loss: 0.2734
# Epoch   3 Batch  100/1077 - Train Accuracy: 0.8004, Validation Accuracy: 0.8260, Loss: 0.2754
# Epoch   3 Batch  120/1077 - Train Accuracy: 0.8469, Validation Accuracy: 0.8050, Loss: 0.2895
# Epoch   3 Batch  140/1077 - Train Accuracy: 0.8129, Validation Accuracy: 0.8008, Loss: 0.2717
# Epoch   3 Batch  160/1077 - Train Accuracy: 0.8562, Validation Accuracy: 0.8153, Loss: 0.2493
# Epoch   3 Batch  180/1077 - Train Accuracy: 0.8133, Validation Accuracy: 0.8182, Loss: 0.2427
# Epoch   3 Batch  200/1077 - Train Accuracy: 0.8242, Validation Accuracy: 0.8391, Loss: 0.2603
# Epoch   3 Batch  220/1077 - Train Accuracy: 0.8475, Validation Accuracy: 0.8292, Loss: 0.2630
# Epoch   3 Batch  240/1077 - Train Accuracy: 0.8395, Validation Accuracy: 0.8239, Loss: 0.2453
# Epoch   3 Batch  260/1077 - Train Accuracy: 0.8757, Validation Accuracy: 0.8271, Loss: 0.2193
# Epoch   3 Batch  280/1077 - Train Accuracy: 0.8355, Validation Accuracy: 0.8285, Loss: 0.2530
# Epoch   3 Batch  300/1077 - Train Accuracy: 0.8211, Validation Accuracy: 0.8548, Loss: 0.2384
# Epoch   3 Batch  320/1077 - Train Accuracy: 0.8313, Validation Accuracy: 0.8320, Loss: 0.2447
# Epoch   3 Batch  340/1077 - Train Accuracy: 0.8528, Validation Accuracy: 0.8349, Loss: 0.2326
# Epoch   3 Batch  360/1077 - Train Accuracy: 0.8379, Validation Accuracy: 0.8512, Loss: 0.2357
# Epoch   3 Batch  380/1077 - Train Accuracy: 0.8453, Validation Accuracy: 0.8551, Loss: 0.2175
# Epoch   3 Batch  400/1077 - Train Accuracy: 0.8355, Validation Accuracy: 0.8583, Loss: 0.2367
# Epoch   3 Batch  420/1077 - Train Accuracy: 0.8711, Validation Accuracy: 0.8477, Loss: 0.2140
# Epoch   3 Batch  440/1077 - Train Accuracy: 0.8391, Validation Accuracy: 0.8363, Loss: 0.2266
# Epoch   3 Batch  460/1077 - Train Accuracy: 0.8602, Validation Accuracy: 0.8498, Loss: 0.2365
# Epoch   3 Batch  480/1077 - Train Accuracy: 0.8146, Validation Accuracy: 0.8484, Loss: 0.2297
# Epoch   3 Batch  500/1077 - Train Accuracy: 0.8512, Validation Accuracy: 0.8675, Loss: 0.2073
# Epoch   3 Batch  520/1077 - Train Accuracy: 0.8891, Validation Accuracy: 0.8299, Loss: 0.1981
# Epoch   3 Batch  540/1077 - Train Accuracy: 0.8914, Validation Accuracy: 0.8466, Loss: 0.1842
# Epoch   3 Batch  560/1077 - Train Accuracy: 0.8316, Validation Accuracy: 0.8540, Loss: 0.2039
# Epoch   3 Batch  580/1077 - Train Accuracy: 0.8664, Validation Accuracy: 0.8661, Loss: 0.1921
# Epoch   3 Batch  600/1077 - Train Accuracy: 0.8285, Validation Accuracy: 0.8622, Loss: 0.2020
# Epoch   3 Batch  620/1077 - Train Accuracy: 0.8641, Validation Accuracy: 0.8594, Loss: 0.1936
# Epoch   3 Batch  640/1077 - Train Accuracy: 0.8903, Validation Accuracy: 0.8640, Loss: 0.1803
# Epoch   3 Batch  660/1077 - Train Accuracy: 0.8809, Validation Accuracy: 0.8629, Loss: 0.1950
# Epoch   3 Batch  680/1077 - Train Accuracy: 0.8597, Validation Accuracy: 0.8565, Loss: 0.1825
# Epoch   3 Batch  700/1077 - Train Accuracy: 0.8770, Validation Accuracy: 0.8651, Loss: 0.1734
# Epoch   3 Batch  720/1077 - Train Accuracy: 0.8758, Validation Accuracy: 0.8491, Loss: 0.2067
# Epoch   3 Batch  740/1077 - Train Accuracy: 0.8438, Validation Accuracy: 0.8587, Loss: 0.1745
# Epoch   3 Batch  760/1077 - Train Accuracy: 0.8625, Validation Accuracy: 0.8704, Loss: 0.2025
# Epoch   3 Batch  780/1077 - Train Accuracy: 0.8336, Validation Accuracy: 0.8491, Loss: 0.2040
# Epoch   3 Batch  800/1077 - Train Accuracy: 0.8703, Validation Accuracy: 0.8707, Loss: 0.1704
# Epoch   3 Batch  820/1077 - Train Accuracy: 0.8824, Validation Accuracy: 0.8849, Loss: 0.1697
# Epoch   3 Batch  840/1077 - Train Accuracy: 0.8578, Validation Accuracy: 0.8888, Loss: 0.1610
# Epoch   3 Batch  860/1077 - Train Accuracy: 0.8627, Validation Accuracy: 0.8761, Loss: 0.1708
# Epoch   3 Batch  880/1077 - Train Accuracy: 0.9113, Validation Accuracy: 0.8608, Loss: 0.1656
# Epoch   3 Batch  900/1077 - Train Accuracy: 0.9145, Validation Accuracy: 0.8977, Loss: 0.1790
# Epoch   3 Batch  920/1077 - Train Accuracy: 0.8777, Validation Accuracy: 0.8800, Loss: 0.1773
# Epoch   3 Batch  940/1077 - Train Accuracy: 0.8734, Validation Accuracy: 0.8764, Loss: 0.1475
# Epoch   3 Batch  960/1077 - Train Accuracy: 0.8650, Validation Accuracy: 0.8810, Loss: 0.1527
# Epoch   3 Batch  980/1077 - Train Accuracy: 0.8711, Validation Accuracy: 0.8665, Loss: 0.1617
# Epoch   3 Batch 1000/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.8981, Loss: 0.1447
# Epoch   3 Batch 1020/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.8686, Loss: 0.1438
# Epoch   3 Batch 1040/1077 - Train Accuracy: 0.9050, Validation Accuracy: 0.8871, Loss: 0.1725
# Epoch   3 Batch 1060/1077 - Train Accuracy: 0.8836, Validation Accuracy: 0.8665, Loss: 0.1472
# Epoch   4 Batch   20/1077 - Train Accuracy: 0.8895, Validation Accuracy: 0.8714, Loss: 0.1169
# Epoch   4 Batch   40/1077 - Train Accuracy: 0.9035, Validation Accuracy: 0.8523, Loss: 0.1398
# Epoch   4 Batch   60/1077 - Train Accuracy: 0.9111, Validation Accuracy: 0.8793, Loss: 0.1286
# Epoch   4 Batch   80/1077 - Train Accuracy: 0.8824, Validation Accuracy: 0.8786, Loss: 0.1310
# Epoch   4 Batch  100/1077 - Train Accuracy: 0.9105, Validation Accuracy: 0.8846, Loss: 0.1356
# Epoch   4 Batch  120/1077 - Train Accuracy: 0.9105, Validation Accuracy: 0.8881, Loss: 0.1604
# Epoch   4 Batch  140/1077 - Train Accuracy: 0.9091, Validation Accuracy: 0.8988, Loss: 0.1379
# Epoch   4 Batch  160/1077 - Train Accuracy: 0.9031, Validation Accuracy: 0.8675, Loss: 0.1215
# Epoch   4 Batch  180/1077 - Train Accuracy: 0.9148, Validation Accuracy: 0.8849, Loss: 0.1231
# Epoch   4 Batch  200/1077 - Train Accuracy: 0.8793, Validation Accuracy: 0.8842, Loss: 0.1386
# Epoch   4 Batch  220/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.8906, Loss: 0.1295
# Epoch   4 Batch  240/1077 - Train Accuracy: 0.9277, Validation Accuracy: 0.8849, Loss: 0.1216
# Epoch   4 Batch  260/1077 - Train Accuracy: 0.9167, Validation Accuracy: 0.8782, Loss: 0.1142
# Epoch   4 Batch  280/1077 - Train Accuracy: 0.8719, Validation Accuracy: 0.8768, Loss: 0.1269
# Epoch   4 Batch  300/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.8825, Loss: 0.1119
# Epoch   4 Batch  320/1077 - Train Accuracy: 0.9047, Validation Accuracy: 0.8782, Loss: 0.1298
# Epoch   4 Batch  340/1077 - Train Accuracy: 0.9009, Validation Accuracy: 0.8711, Loss: 0.1205
# Epoch   4 Batch  360/1077 - Train Accuracy: 0.9117, Validation Accuracy: 0.8810, Loss: 0.1190
# Epoch   4 Batch  380/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.8935, Loss: 0.1111
# Epoch   4 Batch  400/1077 - Train Accuracy: 0.9082, Validation Accuracy: 0.8807, Loss: 0.1265
# Epoch   4 Batch  420/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.8967, Loss: 0.1069
# Epoch   4 Batch  440/1077 - Train Accuracy: 0.8867, Validation Accuracy: 0.8814, Loss: 0.1241
# Epoch   4 Batch  460/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.8963, Loss: 0.1299
# Epoch   4 Batch  480/1077 - Train Accuracy: 0.9071, Validation Accuracy: 0.8864, Loss: 0.1233
# Epoch   4 Batch  500/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.8991, Loss: 0.1038
# Epoch   4 Batch  520/1077 - Train Accuracy: 0.9278, Validation Accuracy: 0.8928, Loss: 0.1035
# Epoch   4 Batch  540/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.8885, Loss: 0.0973
# Epoch   4 Batch  560/1077 - Train Accuracy: 0.9105, Validation Accuracy: 0.8924, Loss: 0.1068
# Epoch   4 Batch  580/1077 - Train Accuracy: 0.9260, Validation Accuracy: 0.8867, Loss: 0.0960
# Epoch   4 Batch  600/1077 - Train Accuracy: 0.9036, Validation Accuracy: 0.9016, Loss: 0.1138
# Epoch   4 Batch  620/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.8821, Loss: 0.1056
# Epoch   4 Batch  640/1077 - Train Accuracy: 0.9115, Validation Accuracy: 0.9070, Loss: 0.1005
# Epoch   4 Batch  660/1077 - Train Accuracy: 0.9117, Validation Accuracy: 0.8860, Loss: 0.1054
# Epoch   4 Batch  680/1077 - Train Accuracy: 0.9036, Validation Accuracy: 0.8675, Loss: 0.0984
# Epoch   4 Batch  700/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.8803, Loss: 0.0848
# Epoch   4 Batch  720/1077 - Train Accuracy: 0.8894, Validation Accuracy: 0.8857, Loss: 0.1075
# Epoch   4 Batch  740/1077 - Train Accuracy: 0.8996, Validation Accuracy: 0.9066, Loss: 0.0913
# Epoch   4 Batch  760/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9094, Loss: 0.1129
# Epoch   4 Batch  780/1077 - Train Accuracy: 0.8840, Validation Accuracy: 0.8977, Loss: 0.1232
# Epoch   4 Batch  800/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.8924, Loss: 0.0900
# Epoch   4 Batch  820/1077 - Train Accuracy: 0.9043, Validation Accuracy: 0.8963, Loss: 0.0897
# Epoch   4 Batch  840/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9023, Loss: 0.0877
# Epoch   4 Batch  860/1077 - Train Accuracy: 0.9323, Validation Accuracy: 0.9137, Loss: 0.0938
# Epoch   4 Batch  880/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.8928, Loss: 0.0941
# Epoch   4 Batch  900/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.8991, Loss: 0.1014
# Epoch   4 Batch  920/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.8967, Loss: 0.0958
# Epoch   4 Batch  940/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.8935, Loss: 0.0825
# Epoch   4 Batch  960/1077 - Train Accuracy: 0.9196, Validation Accuracy: 0.9183, Loss: 0.0879
# Epoch   4 Batch  980/1077 - Train Accuracy: 0.9047, Validation Accuracy: 0.9027, Loss: 0.0943
# Epoch   4 Batch 1000/1077 - Train Accuracy: 0.9226, Validation Accuracy: 0.8967, Loss: 0.0851
# Epoch   4 Batch 1020/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9048, Loss: 0.0789
# Epoch   4 Batch 1040/1077 - Train Accuracy: 0.9317, Validation Accuracy: 0.9144, Loss: 0.0979
# Epoch   4 Batch 1060/1077 - Train Accuracy: 0.9246, Validation Accuracy: 0.8952, Loss: 0.0760
# Epoch   5 Batch   20/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.9048, Loss: 0.0680
# Epoch   5 Batch   40/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9034, Loss: 0.0773
# Epoch   5 Batch   60/1077 - Train Accuracy: 0.9431, Validation Accuracy: 0.9080, Loss: 0.0797
# Epoch   5 Batch   80/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9084, Loss: 0.0774
# Epoch   5 Batch  100/1077 - Train Accuracy: 0.9313, Validation Accuracy: 0.9055, Loss: 0.0777
# Epoch   5 Batch  120/1077 - Train Accuracy: 0.9359, Validation Accuracy: 0.9123, Loss: 0.1001
# Epoch   5 Batch  140/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.8885, Loss: 0.0792
# Epoch   5 Batch  160/1077 - Train Accuracy: 0.9395, Validation Accuracy: 0.9062, Loss: 0.0691
# Epoch   5 Batch  180/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.8995, Loss: 0.0699
# Epoch   5 Batch  200/1077 - Train Accuracy: 0.9145, Validation Accuracy: 0.9144, Loss: 0.0869
# Epoch   5 Batch  220/1077 - Train Accuracy: 0.9634, Validation Accuracy: 0.9002, Loss: 0.0718
# Epoch   5 Batch  240/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9052, Loss: 0.0738
# Epoch   5 Batch  260/1077 - Train Accuracy: 0.9382, Validation Accuracy: 0.9126, Loss: 0.0652
# Epoch   5 Batch  280/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.9038, Loss: 0.0790
# Epoch   5 Batch  300/1077 - Train Accuracy: 0.9675, Validation Accuracy: 0.9158, Loss: 0.0623
# Epoch   5 Batch  320/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9201, Loss: 0.0834
# Epoch   5 Batch  340/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9052, Loss: 0.0707
# Epoch   5 Batch  360/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.9187, Loss: 0.0681
# Epoch   5 Batch  380/1077 - Train Accuracy: 0.9430, Validation Accuracy: 0.8970, Loss: 0.0663
# Epoch   5 Batch  400/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9134, Loss: 0.0759
# Epoch   5 Batch  420/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9109, Loss: 0.0605
# Epoch   5 Batch  440/1077 - Train Accuracy: 0.9035, Validation Accuracy: 0.8956, Loss: 0.0824
# Epoch   5 Batch  460/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.8981, Loss: 0.0832
# Epoch   5 Batch  480/1077 - Train Accuracy: 0.9359, Validation Accuracy: 0.8981, Loss: 0.0695
# Epoch   5 Batch  500/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9130, Loss: 0.0619
# Epoch   5 Batch  520/1077 - Train Accuracy: 0.9446, Validation Accuracy: 0.9165, Loss: 0.0618
# Epoch   5 Batch  540/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9098, Loss: 0.0572
# Epoch   5 Batch  560/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9077, Loss: 0.0633
# Epoch   5 Batch  580/1077 - Train Accuracy: 0.9442, Validation Accuracy: 0.9066, Loss: 0.0524
# Epoch   5 Batch  600/1077 - Train Accuracy: 0.9338, Validation Accuracy: 0.9091, Loss: 0.0718
# Epoch   5 Batch  620/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9013, Loss: 0.0616
# Epoch   5 Batch  640/1077 - Train Accuracy: 0.9550, Validation Accuracy: 0.9119, Loss: 0.0620
# Epoch   5 Batch  660/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9059, Loss: 0.0596
# Epoch   5 Batch  680/1077 - Train Accuracy: 0.9256, Validation Accuracy: 0.8984, Loss: 0.0625
# Epoch   5 Batch  700/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9112, Loss: 0.0526
# Epoch   5 Batch  720/1077 - Train Accuracy: 0.9128, Validation Accuracy: 0.9219, Loss: 0.0717
# Epoch   5 Batch  740/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9197, Loss: 0.0563
# Epoch   5 Batch  760/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9268, Loss: 0.0724
# Epoch   5 Batch  780/1077 - Train Accuracy: 0.9039, Validation Accuracy: 0.9144, Loss: 0.0839
# Epoch   5 Batch  800/1077 - Train Accuracy: 0.9398, Validation Accuracy: 0.9205, Loss: 0.0597
# Epoch   5 Batch  820/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9293, Loss: 0.0562
# Epoch   5 Batch  840/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9350, Loss: 0.0544
# Epoch   5 Batch  860/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.9300, Loss: 0.0601
# Epoch   5 Batch  880/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9428, Loss: 0.0646
# Epoch   5 Batch  900/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9311, Loss: 0.0628
# Epoch   5 Batch  920/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9304, Loss: 0.0584
# Epoch   5 Batch  940/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9244, Loss: 0.0568
# Epoch   5 Batch  960/1077 - Train Accuracy: 0.9416, Validation Accuracy: 0.9151, Loss: 0.0568
# Epoch   5 Batch  980/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9233, Loss: 0.0656
# Epoch   5 Batch 1000/1077 - Train Accuracy: 0.9401, Validation Accuracy: 0.9226, Loss: 0.0592
# Epoch   5 Batch 1020/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9279, Loss: 0.0488
# Epoch   5 Batch 1040/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9364, Loss: 0.0648
# Epoch   5 Batch 1060/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.9112, Loss: 0.0572
# Epoch   6 Batch   20/1077 - Train Accuracy: 0.9336, Validation Accuracy: 0.9325, Loss: 0.0488
# Epoch   6 Batch   40/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.9283, Loss: 0.0534
# Epoch   6 Batch   60/1077 - Train Accuracy: 0.9557, Validation Accuracy: 0.9002, Loss: 0.0530
# Epoch   6 Batch   80/1077 - Train Accuracy: 0.9430, Validation Accuracy: 0.9165, Loss: 0.0523
# Epoch   6 Batch  100/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9112, Loss: 0.0501
# Epoch   6 Batch  120/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9165, Loss: 0.0730
# Epoch   6 Batch  140/1077 - Train Accuracy: 0.9564, Validation Accuracy: 0.9048, Loss: 0.0492
# Epoch   6 Batch  160/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9247, Loss: 0.0424
# Epoch   6 Batch  180/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9212, Loss: 0.0447
# Epoch   6 Batch  200/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9187, Loss: 0.0561
# Epoch   6 Batch  220/1077 - Train Accuracy: 0.9757, Validation Accuracy: 0.9304, Loss: 0.0511
# Epoch   6 Batch  240/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9418, Loss: 0.0470
# Epoch   6 Batch  260/1077 - Train Accuracy: 0.9182, Validation Accuracy: 0.9240, Loss: 0.0409
# Epoch   6 Batch  280/1077 - Train Accuracy: 0.9285, Validation Accuracy: 0.9300, Loss: 0.0562
# Epoch   6 Batch  300/1077 - Train Accuracy: 0.9716, Validation Accuracy: 0.9336, Loss: 0.0427
# Epoch   6 Batch  320/1077 - Train Accuracy: 0.9473, Validation Accuracy: 0.9297, Loss: 0.0563
# Epoch   6 Batch  340/1077 - Train Accuracy: 0.9692, Validation Accuracy: 0.9229, Loss: 0.0476
# Epoch   6 Batch  360/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9450, Loss: 0.0450
# Epoch   6 Batch  380/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9283, Loss: 0.0430
# Epoch   6 Batch  400/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9197, Loss: 0.0542
# Epoch   6 Batch  420/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9286, Loss: 0.0412
# Epoch   6 Batch  440/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.8970, Loss: 0.0557
# Epoch   6 Batch  460/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9244, Loss: 0.0618
# Epoch   6 Batch  480/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9279, Loss: 0.0515
# Epoch   6 Batch  500/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.9276, Loss: 0.0429
# Epoch   6 Batch  520/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9261, Loss: 0.0481
# Epoch   6 Batch  540/1077 - Train Accuracy: 0.9738, Validation Accuracy: 0.9251, Loss: 0.0409
# Epoch   6 Batch  560/1077 - Train Accuracy: 0.9437, Validation Accuracy: 0.9318, Loss: 0.0479
# Epoch   6 Batch  580/1077 - Train Accuracy: 0.9576, Validation Accuracy: 0.9322, Loss: 0.0353
# Epoch   6 Batch  600/1077 - Train Accuracy: 0.9524, Validation Accuracy: 0.9357, Loss: 0.0493
# Epoch   6 Batch  620/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9325, Loss: 0.0449
# Epoch   6 Batch  640/1077 - Train Accuracy: 0.9650, Validation Accuracy: 0.9244, Loss: 0.0400
# Epoch   6 Batch  660/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9265, Loss: 0.0430
# Epoch   6 Batch  680/1077 - Train Accuracy: 0.9412, Validation Accuracy: 0.9379, Loss: 0.0496
# Epoch   6 Batch  700/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9339, Loss: 0.0362
# Epoch   6 Batch  720/1077 - Train Accuracy: 0.9272, Validation Accuracy: 0.9428, Loss: 0.0510
# Epoch   6 Batch  740/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9425, Loss: 0.0387
# Epoch   6 Batch  760/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9215, Loss: 0.0503
# Epoch   6 Batch  780/1077 - Train Accuracy: 0.9086, Validation Accuracy: 0.9272, Loss: 0.0598
# Epoch   6 Batch  800/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.9400, Loss: 0.0418
# Epoch   6 Batch  820/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9382, Loss: 0.0407
# Epoch   6 Batch  840/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9482, Loss: 0.0376
# Epoch   6 Batch  860/1077 - Train Accuracy: 0.9368, Validation Accuracy: 0.9602, Loss: 0.0445
# Epoch   6 Batch  880/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9411, Loss: 0.0514
# Epoch   6 Batch  900/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9464, Loss: 0.0491
# Epoch   6 Batch  920/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9382, Loss: 0.0420
# Epoch   6 Batch  940/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9290, Loss: 0.0411
# Epoch   6 Batch  960/1077 - Train Accuracy: 0.9554, Validation Accuracy: 0.9244, Loss: 0.0385
# Epoch   6 Batch  980/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9361, Loss: 0.0497
# Epoch   6 Batch 1000/1077 - Train Accuracy: 0.9468, Validation Accuracy: 0.9503, Loss: 0.0460
# Epoch   6 Batch 1020/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9478, Loss: 0.0357
# Epoch   6 Batch 1040/1077 - Train Accuracy: 0.9486, Validation Accuracy: 0.9339, Loss: 0.0452
# Epoch   6 Batch 1060/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9361, Loss: 0.0369
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # Convert the sentence to lowercase
    lowercase_sentence = sentence.lower()
    
    # Convert words into ids using vocab_to_int
    # Convert words not in the vocabulary, to the <UNK> word id.
    src_line_token_ids = []
    for srcWord in lowercase_sentence.split():
        src_line_token_ids.append(vocab_to_int.get(srcWord, vocab_to_int['<UNK>']))
   
    return src_line_token_ids


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [49, 138, 207, 183, 179, 193, 23]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [223, 264, 8, 173, 213, 158, 75, 100, 1]
#   French Words: il a l' vieux un nouveau camion . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
